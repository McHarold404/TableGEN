# %% [markdown]
# ## Notebook for Manual Analysis of Generated Tables

# %%
import pandas as pd
import numpy as np
import json
from utils.utils import *
import pprint
from eval.eval import *
from post_processing.post_processing import *
from utils.table_utils import *
from model_inference.gpt import *
from model_inference.llama import *
from model_inference.gemini import *
eval_rows = 50
model_output_file = "model_outputs/llama_baseline_2610_117AM/tables_gpt_trial.json"
statements ="model_outputs/llama_baseline_2610_117AM/ai_response.json"
headers = "model_outputs/llama_baseline_2610_117AM/headers.json"
gold_table_file = "data/rotowire/test.text"

# %%
statements = read_file(statements)
headers = read_file(headers)

# %%
### Reading Gold Labels
gold_texts = []
with open(gold_table_file,"r") as f:
    lines = [line.strip() for line in f.readlines()]

# %%
## Read outputs from files.
with open(model_output_file,'r') as f:
     output = json.load(f)
extracted_tables = extract_tables_from_responses(output) 
# if reading and extractind directly from gpt model.  
# if model responses are saved and read from a file, helpful for testing and multiple evaluations.
output_tables_rotowire = generate_output_lines(output_path ='data/rotowire/test.data',end_line= eval_rows) ### gold tables
output_tables_strucbench = generate_output_lines(output_path ='data/Strucbench/test.data',end_line= eval_rows) ### gold tables
#print(extracted_tables)

# Now you can process each extracted table

gold_table_player_rotowire = []
gold_table_team_rotowire = []
gold_table_player_strucbench = []
gold_table_team_strucbench = []
model_output_team = []
model_output_player = []
for model_output,gold_label_rotowire, gold_label_strucbench in zip(extracted_tables,output_tables_rotowire,output_tables_strucbench):
    #data_point = tables['data_point']

     gold_tables_rotowire = separate_tables(gold_label_rotowire)
     gold_tables_strucbench = separate_tables(gold_label_strucbench)
     try: 
          model_output_tt = prune_table(model_output['Team'])
     except:
          model_output_tt = ""
     try:     
          model_output_pt = prune_table(model_output['Player'])
     except:
          model_output_pt = ""

     #model_tables = separate_tables(model_output.strip(['Final Answer','\n',':')])
     #print(model_tables)
     # print(model_tables['Player'])
     # print("--------------------------")
     # print(model_tables['Team'])
     #print("---------------------------")
     #print(gold_tables['Player'])
     #print("---------------------------")
     #print(gold_tables['Team'])
     #print("---------------------------")

     model_output_team.append(model_output_tt)
     model_output_player.append(model_output_pt) 
     gold_table_player_rotowire.append( gold_tables_rotowire['Player'])
     gold_table_team_rotowire.append(gold_tables_rotowire['Team'])
     gold_table_player_strucbench.append( gold_tables_strucbench['Player'])
     gold_table_team_strucbench.append(gold_tables_strucbench['Team'])
# Out:
# Table 'Team' found for data_point 0
# Table 'Player' found for data_point 0
# Table 'Upcoming Games' found for data_point 0
# Table 'Standings' found for data_point 0
# Table 'Team' found for data_point 1
# Table 'Player' found for data_point 1
# Table 'Upcoming Games' found for data_point 1
# Table 'Team' found for data_point 2
# Table 'Player' found for data_point 2
# Table 'Upcoming Games' found for data_point 2
# Table 'Team' found for data_point 3
# Table 'Player' found for data_point 3
# Table 'Upcoming Games' found for data_point 3
# Table 'Team' found for data_point 4
# Table 'Player' found for data_point 4
# Table 'Upcoming Games' found for data_point 4
# Table 'Conference Standing' found for data_point 4
# Table 'Team' found for data_point 5
# Table 'Player' found for data_point 5
# Table 'Upcoming Games' found for data_point 5
# Table 'Team' found for data_point 6
# Table 'Player' found for data_point 6
# Table 'Game Series' found for data_point 6
# Table 'Player Status' found for data_point 6
# Table 'Team' found for data_point 7
# Table 'Player' found for data_point 7
# Table 'Upcoming Games' found for data_point 7
# Table 'Player' found for data_point 8
# Table 'Team' found for data_point 9
# Table 'Player' found for data_point 9
# Table 'Team' found for data_point 10
# Table 'Conference Position' found for data_point 10
# Table 'Player' found for data_point 10
# Table 'Team' found for data_point 11
# Table 'Player' found for data_point 11
# Table 'Team' found for data_point 12
# Table 'Player' found for data_point 12
# Table 'Bench Unit' found for data_point 12
# Table 'Team' found for data_point 13
# Table 'Player' found for data_point 13
# Table 'Upcoming Games' found for data_point 13
# Table 'Standings' found for data_point 13
# Table 'Team' found for data_point 14
# Table 'Player' found for data_point 14
# Table 'Upcoming Games' found for data_point 14
# Table 'Game Results' found for data_point 15
# Table 'Player Statistics' found for data_point 15
# Table 'Upcoming Games' found for data_point 15
# Table 'Team' found for data_point 16
# Table 'Player' found for data_point 16
# Table 'Points Score' found for data_point 16
# Table 'Team' found for data_point 17
# Table 'Player' found for data_point 17
# Table 'Team Overview' found for data_point 18
# Table 'Player Stats' found for data_point 18
# Table 'Upcoming Games' found for data_point 18
# Table 'Player' found for data_point 19
# Table 'Other Information' found for data_point 19
# Table 'Player' found for data_point 20
# Table 'Team' found for data_point 20
# Table 'Team' found for data_point 21
# Table 'Player' found for data_point 21
# Table 'Upcoming Games' found for data_point 21
# Table 'Division Standings' found for data_point 21
# Table 'Player' found for data_point 22
# Table 'Team' found for data_point 22
# Table 'Team' found for data_point 23
# Table 'Player' found for data_point 23
# Table 'Upcoming Games' found for data_point 23
# Table 'Team' found for data_point 24
# Table 'Team' found for data_point 25
# Table 'Player' found for data_point 25
# Table 'Team Records' found for data_point 25
# Table 'Team' found for data_point 26
# Table 'Player' found for data_point 26
# Table 'Upcoming Games' found for data_point 26
# Table 'Team' found for data_point 27
# Table 'Player' found for data_point 27
# Table 'Upcoming Games' found for data_point 27
# Table 'Team' found for data_point 28
# Table 'Player' found for data_point 28
# Table 'Upcoming Games' found for data_point 28
# Table 'Not Played' found for data_point 28
# Table 'Team' found for data_point 29
# Table 'Player' found for data_point 29
# Table 'Team' found for data_point 30
# Table 'Player' found for data_point 30
# Table 'Team' found for data_point 31
# Table 'Player' found for data_point 31
# Table 'Upcoming Games' found for data_point 31
# Table 'Goals' found for data_point 31
# Table 'Team' found for data_point 32
# Table 'Player' found for data_point 32
# Table 'Upcoming Games' found for data_point 32
# Table 'Team' found for data_point 33
# Table 'Player' found for data_point 33
# Table 'Upcoming Games' found for data_point 33
# Table 'Team' found for data_point 34
# Table 'Player' found for data_point 34
# Table 'Upcoming Games' found for data_point 34
# Table 'Rested Players' found for data_point 34
# Table 'Team' found for data_point 35
# Table 'Player' found for data_point 35
# Table 'Upcoming Games' found for data_point 35
# Table 'Team' found for data_point 36
# Table 'Player' found for data_point 36
# Table 'Upcoming Games' found for data_point 36
# Table 'Team' found for data_point 37
# Table 'Player' found for data_point 37
# Table 'Team Game Statistics' found for data_point 38
# Table 'Individual Player Statistics' found for data_point 38
# Table 'Upcoming Games' found for data_point 38
# Table 'Player' found for data_point 39
# Table 'Team' found for data_point 40
# Table 'Player' found for data_point 40
# Table 'Miscellaneous Information' found for data_point 40
# Table 'Team' found for data_point 41
# Table 'Player' found for data_point 41
# Table 'Upcoming Games' found for data_point 41
# Table 'Team' found for data_point 42
# Table 'Player' found for data_point 42
# Table 'Team' found for data_point 43
# Table 'Player' found for data_point 43
# Table 'Team' found for data_point 44
# Table 'Player' found for data_point 44
# Table 'Upcoming Games' found for data_point 44
# Table 'Team' found for data_point 45
# Table 'Player' found for data_point 45
# Table 'Team' found for data_point 46
# Table 'Player' found for data_point 46
# Table 'Team' found for data_point 47
# Table 'Player' found for data_point 47
# Table 'Team' found for data_point 48
# Table 'Player' found for data_point 48
# Table 'Team' found for data_point 49
# Table 'Player' found for data_point 49

# %%
### Reading Gold Labels
gold_texts = []
with open(gold_table_file,"r") as f:
    lines = [line.strip() for line in f.readlines()]

# %%
idx = 6

# %%
# %clear
import textwrap
print(textwrap.fill(lines[idx],width=100))
# Out:
# The second - seed Cleveland Cavaliers (40) completed their sweep of the seventh - seed Boston
# Celtics (0 - 4) in a 101 - 93 slugfest Sunday. Cleveland came out with purpose in the first half,
# wining both of the first two quarters to go into the break with 57 - 36 lead. Coach David Blatt
# could have taken the game easy with the Cavs up 30 in the series, but he opted to push the
# accelerator to the floor and used his big guns for most of the game to ensure a win and an end to
# the Cavs' first - round series. LeBron James played a team - high 46 minutes and was followed
# closely by Kyrie Irving with 43 minutes of his own. Kevin Love was forced from the game in the first
# quarter with what appeared to be a dislocated left shoulder after Celtics big man Kelly Olynyk
# appeared to pull down on Love's arm while fighting for a rebound. Love was n't the only player to be
# forced from the game, and the Love/Olynyk incident was n't the only physical altercation. In the
# second quarter, Kendrick Perkins put a hard screen on Jae Crowder, pushing Crowder in his face and
# forcing him to the ground before antagonizing Crowder with a tap to the face with a closed fist.
# Both Perkins and Crowder were assessed technical fouls, and Perkins earned a flagrant - 1 foul for
# the tap to Crowder's face. Shortly after halftime, Crowder was hit in the face by a backhand from
# J.R. Smith. Smith was given a flagrant - 2 and automatically ejected from the game as a result.
# Crowder injured his knee during the Smith incident and left the game with a left knee sprain, unable
# to return. The Celtics made a run in the third quarter, outscoring the Cavs 25 - 13 in the third
# window, but it was n't enough. Cleveland carried a nine - point lead into the fourth quarter and
# never let Boston get closer than a six - point divide at 99 - 93 with under a minute left in the
# game. The Cavaliers will advance to the Eastern Conference semifinals, and they'll play the winner
# of the Bulls/Bucks series that is currently at 3 - 1 with the Bulls holding the advantage. Kevin
# Love's status will be updated after he gets back to Cleveland and undergoes tests with the team's
# doctors. Smith and Perkins appear in line for suspensions, and a judgment on their statuses will
# likely be handed down before the start of the conference semifinals.

# %%
input = statements[idx]['response']
header = headers[idx]['response']
lol = dict()
lmao_dict = []
tex = header + input
tex = tex.strip('\n')
lmao =ask_chatgpt(text=tex,prompt_path="prompts/rotowire_gpt4o_make_tables.txt")
lol['response'] = lmao
lmao_dict.append(lol)
pprint.pprint(lmao)
tables = extract_tables_from_responses(lmao_dict)
# Out:
# jere
# ---------------------------------------------------------------------------
# LocalProtocolError                        Traceback (most recent call last)
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/http11.py:142, in HTTP11Connection._send_request_headers(self, request)
#     141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
# --> 142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#     147 self._send_event(event, timeout=timeout)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/h11/_events.py:96, in Request.__init__(self, method, headers, target, http_version, _parsed)
#      94 else:
#      95     object.__setattr__(
# ---> 96         self, "headers", normalize_and_validate(headers, _parsed=_parsed)
#      97     )
#      98 if not _parsed:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/h11/_headers.py:164, in normalize_and_validate(headers, _parsed)
#     163     validate(_field_name_re, name, "Illegal header name {!r}", name)
# --> 164     validate(_field_value_re, value, "Illegal header value {!r}", value)
#     165 assert isinstance(name, bytes)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/h11/_util.py:91, in validate(regex, data, msg, *format_args)
#      90         msg = msg.format(*format_args)
# ---> 91     raise LocalProtocolError(msg)
#      92 return match.groupdict()
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_transports/default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/http11.py:92, in HTTP11Connection.handle_request(self, request)
#      89 with Trace(
#      90     "send_request_headers", logger, request, kwargs
#      91 ) as trace:
# ---> 92     self._send_request_headers(**kwargs)
#      93 with Trace("send_request_body", logger, request, kwargs) as trace:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/http11.py:141, in HTTP11Connection._send_request_headers(self, request)
#     139 timeout = timeouts.get("write", None)
# --> 141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
#     142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/openai/_base_client.py:990, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     989 try:
# --> 990     response = self._client.send(
#     991         request,
#     992         stream=stream or self._should_stream_response_body(request=request),
#     993         **kwargs,
#     994     )
#     995 except httpx.TimeoutException as err:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_transports/default.py:232, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
# --> 232 with map_httpcore_exceptions():
#     233     resp = self._pool.handle_request(req)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_transports/default.py:86, in map_httpcore_exceptions()
#      85 message = str(exc)
# ---> 86 raise mapped_exc(message) from exc
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# During handling of the above exception, another exception occurred:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/http11.py:142, in HTTP11Connection._send_request_headers(self, request)
#     141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
# --> 142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#     147 self._send_event(event, timeout=timeout)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/h11/_events.py:96, in Request.__init__(self, method, headers, target, http_version, _parsed)
#      94 else:
#      95     object.__setattr__(
# ---> 96         self, "headers", normalize_and_validate(headers, _parsed=_parsed)
#      97     )
#      98 if not _parsed:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/h11/_headers.py:164, in normalize_and_validate(headers, _parsed)
#     163     validate(_field_name_re, name, "Illegal header name {!r}", name)
# --> 164     validate(_field_value_re, value, "Illegal header value {!r}", value)
#     165 assert isinstance(name, bytes)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/h11/_util.py:91, in validate(regex, data, msg, *format_args)
#      90         msg = msg.format(*format_args)
# ---> 91     raise LocalProtocolError(msg)
#      92 return match.groupdict()
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_transports/default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/http11.py:92, in HTTP11Connection.handle_request(self, request)
#      89 with Trace(
#      90     "send_request_headers", logger, request, kwargs
#      91 ) as trace:
# ---> 92     self._send_request_headers(**kwargs)
#      93 with Trace("send_request_body", logger, request, kwargs) as trace:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/http11.py:141, in HTTP11Connection._send_request_headers(self, request)
#     139 timeout = timeouts.get("write", None)
# --> 141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
#     142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/openai/_base_client.py:990, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     989 try:
# --> 990     response = self._client.send(
#     991         request,
#     992         stream=stream or self._should_stream_response_body(request=request),
#     993         **kwargs,
#     994     )
#     995 except httpx.TimeoutException as err:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_transports/default.py:232, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
# --> 232 with map_httpcore_exceptions():
#     233     resp = self._pool.handle_request(req)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_transports/default.py:86, in map_httpcore_exceptions()
#      85 message = str(exc)
# ---> 86 raise mapped_exc(message) from exc
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# During handling of the above exception, another exception occurred:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/http11.py:142, in HTTP11Connection._send_request_headers(self, request)
#     141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
# --> 142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#     147 self._send_event(event, timeout=timeout)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/h11/_events.py:96, in Request.__init__(self, method, headers, target, http_version, _parsed)
#      94 else:
#      95     object.__setattr__(
# ---> 96         self, "headers", normalize_and_validate(headers, _parsed=_parsed)
#      97     )
#      98 if not _parsed:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/h11/_headers.py:164, in normalize_and_validate(headers, _parsed)
#     163     validate(_field_name_re, name, "Illegal header name {!r}", name)
# --> 164     validate(_field_value_re, value, "Illegal header value {!r}", value)
#     165 assert isinstance(name, bytes)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/h11/_util.py:91, in validate(regex, data, msg, *format_args)
#      90         msg = msg.format(*format_args)
# ---> 91     raise LocalProtocolError(msg)
#      92 return match.groupdict()
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_transports/default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/http11.py:92, in HTTP11Connection.handle_request(self, request)
#      89 with Trace(
#      90     "send_request_headers", logger, request, kwargs
#      91 ) as trace:
# ---> 92     self._send_request_headers(**kwargs)
#      93 with Trace("send_request_body", logger, request, kwargs) as trace:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_sync/http11.py:141, in HTTP11Connection._send_request_headers(self, request)
#     139 timeout = timeouts.get("write", None)
# --> 141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
#     142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/openai/_base_client.py:990, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     989 try:
# --> 990     response = self._client.send(
#     991         request,
#     992         stream=stream or self._should_stream_response_body(request=request),
#     993         **kwargs,
#     994     )
#     995 except httpx.TimeoutException as err:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_transports/default.py:232, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
# --> 232 with map_httpcore_exceptions():
#     233     resp = self._pool.handle_request(req)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/httpx/_transports/default.py:86, in map_httpcore_exceptions()
#      85 message = str(exc)
# ---> 86 raise mapped_exc(message) from exc
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[8], line 7
#       5 tex = header + input
#       6 tex = tex.strip('\n')
# ----> 7 lmao =ask_chatgpt(text=tex,prompt_path="prompts/rotowire_gpt4o_make_tables.txt")
#       8 lol['response'] = lmao
#       9 lmao_dict.append(lol)
#
# File ~/Desktop/ASU/Research/Inference/Baselines/model_inference/gpt.py:165, in ask_chatgpt(text, prompt_path)
#     163 model_name = "gpt-4o-mini"  # or "gpt-3.5-turbo" if you want a different model
#     164 # Send the prompt to the model
# --> 165 response = client.chat.completions.create(
#     166 model=model_name,
#     167 messages=[
#     168     {'role' : "system" , "content" : prompt },
#     169     {'role': "user" , "content": text}
#     170 ],
#     171 temperature=0.1,
#     172 top_p=0.1
#     173 )
#     175 # Return the response content
#     176 return response.choices[0].message.content
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/openai/_utils/_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     272             msg = f"Missing required argument: {quote(missing[0])}"
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/openai/resources/chat/completions.py:742, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     704 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     705 def create(
#     706     self,
#    (...)
#     739     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     740 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     741     validate_response_format(response_format)
# --> 742     return self._post(
#     743         "/chat/completions",
#     744         body=maybe_transform(
#     745             {
#     746                 "messages": messages,
#     747                 "model": model,
#     748                 "frequency_penalty": frequency_penalty,
#     749                 "function_call": function_call,
#     750                 "functions": functions,
#     751                 "logit_bias": logit_bias,
#     752                 "logprobs": logprobs,
#     753                 "max_completion_tokens": max_completion_tokens,
#     754                 "max_tokens": max_tokens,
#     755                 "metadata": metadata,
#     756                 "n": n,
#     757                 "parallel_tool_calls": parallel_tool_calls,
#     758                 "presence_penalty": presence_penalty,
#     759                 "response_format": response_format,
#     760                 "seed": seed,
#     761                 "service_tier": service_tier,
#     762                 "stop": stop,
#     763                 "store": store,
#     764                 "stream": stream,
#     765                 "stream_options": stream_options,
#     766                 "temperature": temperature,
#     767                 "tool_choice": tool_choice,
#     768                 "tools": tools,
#     769                 "top_logprobs": top_logprobs,
#     770                 "top_p": top_p,
#     771                 "user": user,
#     772             },
#     773             completion_create_params.CompletionCreateParams,
#     774         ),
#     775         options=make_request_options(
#     776             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     777         ),
#     778         cast_to=ChatCompletion,
#     779         stream=stream or False,
#     780         stream_cls=Stream[ChatCompletionChunk],
#     781     )
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/openai/_base_client.py:1277, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1263 def post(
#    1264     self,
#    1265     path: str,
#    (...)
#    1272     stream_cls: type[_StreamT] | None = None,
#    1273 ) -> ResponseT | _StreamT:
#    1274     opts = FinalRequestOptions.construct(
#    1275         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1276     )
# -> 1277     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/openai/_base_client.py:954, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     951 else:
#     952     retries_taken = 0
# --> 954 return self._request(
#     955     cast_to=cast_to,
#     956     options=options,
#     957     stream=stream,
#     958     stream_cls=stream_cls,
#     959     retries_taken=retries_taken,
#     960 )
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/openai/_base_client.py:1014, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1011 log.debug("Encountered Exception", exc_info=True)
#    1013 if remaining_retries > 0:
# -> 1014     return self._retry_request(
#    1015         input_options,
#    1016         cast_to,
#    1017         retries_taken=retries_taken,
#    1018         stream=stream,
#    1019         stream_cls=stream_cls,
#    1020         response_headers=None,
#    1021     )
#    1023 log.debug("Raising connection error")
#    1024 raise APIConnectionError(request=request) from err
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/openai/_base_client.py:1092, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1088 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1089 # different thread if necessary.
#    1090 time.sleep(timeout)
# -> 1092 return self._request(
#    1093     options=options,
#    1094     cast_to=cast_to,
#    1095     retries_taken=retries_taken + 1,
#    1096     stream=stream,
#    1097     stream_cls=stream_cls,
#    1098 )
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/openai/_base_client.py:1014, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1011 log.debug("Encountered Exception", exc_info=True)
#    1013 if remaining_retries > 0:
# -> 1014     return self._retry_request(
#    1015         input_options,
#    1016         cast_to,
#    1017         retries_taken=retries_taken,
#    1018         stream=stream,
#    1019         stream_cls=stream_cls,
#    1020         response_headers=None,
#    1021     )
#    1023 log.debug("Raising connection error")
#    1024 raise APIConnectionError(request=request) from err
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/openai/_base_client.py:1092, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1088 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1089 # different thread if necessary.
#    1090 time.sleep(timeout)
# -> 1092 return self._request(
#    1093     options=options,
#    1094     cast_to=cast_to,
#    1095     retries_taken=retries_taken + 1,
#    1096     stream=stream,
#    1097     stream_cls=stream_cls,
#    1098 )
#
# File ~/miniconda3/envs/tablegen/lib/python3.12/site-packages/openai/_base_client.py:1024, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1014         return self._retry_request(
#    1015             input_options,
#    1016             cast_to,
#    (...)
#    1020             response_headers=None,
#    1021         )
#    1023     log.debug("Raising connection error")
# -> 1024     raise APIConnectionError(request=request) from err
#    1026 log.debug(
#    1027     'HTTP Response: %s %s "%i %s" %s',
#    1028     request.method,
#    (...)
#    1032     response.headers,
#    1033 )
#    1034 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.

# %%
convert_to_df(tables[0]['Team'])
# Out:
#            Final Score Series Lead Half Time Score Third Quarter Score  \
# 0  Cleveland Cavaliers         101             3-0               57-36
# 1       Boston Celtics          93
#
#   Fourth Quarter Score Advancement                             Next Opponent  \
# 0                   13              Advance to Eastern Conference semifinals
# 1                   25
#
#
# 0  Winner of Bulls/Bucks series
# 1

# %%
convert_to_df(tables[0]['Player'])
# Out:
#      Minutes Played Injury Status                     Fouls  \
# 0      LeBron James            46
# 1      Kyrie Irving            43
# 2        Kevin Love                Dislocated left shoulder
# 3      Kelly Olynyk
# 4  Kendrick Perkins
# 5       Jae Crowder                        Left knee sprain
# 6        J.R. Smith
#
#               Ejection Status Suspension Status  \
# 0
# 1
# 2
# 3
# 4  Technical foul, Flagrant-1
# 5              Technical foul           Ejected
# 6                  Flagrant-2           Ejected
#
#
# 0
# 1
# 2
# 3
# 4  Appears in line for suspension
# 5  Appears in line for suspension
# 6  Appears in line for suspension

# %%
convert_to_df(gold_table_team_rotowire[idx])
# Out:
#              Percentage of field goals Losses Total points  \
# 0    Celtics                                4           93
# 1  Cavaliers                        40                 101
#
#   Points in 3rd quarter Wins
# 0                    25    0
# 1                    13

# %%
convert_to_df(gold_table_player_rotowire[idx])
# Out:
#                     3-pointers made Minutes played Personal fouls  \
# 0      LeBron James                             46
# 1        Kevin Love
# 2          JR Smith               2
# 3      Kyrie Irving                             43
# 4  Kendrick Perkins                                             1
# 5      Kelly Olynyk
#
#   Total rebounds Steals
# 0
# 1              1
# 2                     2
# 3
# 4
# 5              1

# %%
convert_to_df(gold_table_team_strucbench[idx])

# %%
convert_to_df(gold_table_player_strucbench[idx])

# %%
te = """ The Cleveland Cavaliers completed their sweep of the Boston Celtics with a 101-93 win on Sunday.
The Cleveland Cavaliers entered the game with a 3-0 lead in the series.
The Cleveland Cavaliers won both of the first two quarters to take a 57-36 lead at halftime.
Coach David Blatt chose to play his key players for most of the game to ensure a win.
LeBron James played 46 minutes in the game.
Kyrie Irving played 43 minutes in the game.
Kevin Love was forced from the game in the first quarter with a dislocated left shoulder.
Kelly Olynyk pulled down on Kevin Love's arm while fighting for a rebound, causing Love's injury.
Kendrick Perkins put a hard screen on Jae Crowder in the second quarter.
Kendrick Perkins was assessed a technical foul and a flagrant-1 foul for his actions.
Jae Crowder was assessed a technical foul for his response to Kendrick Perkins' screen.
J.R. Smith hit Jae Crowder in the face with a backhand in the third quarter.
J.R. Smith was given a flagrant-2 foul and automatically ejected from the game.
Jae Crowder injured his knee during the J.R. Smith incident and left the game.
Jae Crowder suffered a left knee sprain and was unable to return to the game.
The Boston Celtics outscored the Cleveland Cavaliers 25-13 in the third quarter.
The Cleveland Cavaliers carried a nine-point lead into the fourth quarter.
The Cleveland Cavaliers never let the Boston Celtics get closer than a six-point divide in the fourth quarter.
The Cleveland Cavaliers will advance to the Eastern Conference semifinals.
The Cleveland Cavaliers will play the winner of the Bulls/Bucks series in the Eastern Conference semifinals.
Kevin Love's status will be updated after he undergoes tests with the team's doctors.
J.R. Smith and Kendrick Perkins appear in line for suspensions for their actions in the game. 
Table Headers:
{
    "Team" : {
        "row_headers" : ["Cleveland Cavaliers", "Boston Celtics"],
        "column_headers" : ["Final Score", "Series Lead", "Half Time Score", "Third Quarter Score", "Fourth Quarter Score", "Advancement", "Next Opponent"]
    },
    "Player" : {
        "row_headers" : ["LeBron James", "Kyrie Irving", "Kevin Love", "Kelly Olynyk", "Kendrick Perkins", "Jae Crowder", "J.R. Smith"],
        "col_headers" : ["Minutes Played", "Injury Status", "Fouls", "Ejection Status", "Suspension Status"]
    }
}
"""

# %%
pprint.pprint(ask_chatgpt(text=(input+header)('\n').strip('\ '),prompt_path="prompts/rotowire_gpt4o_make_tables.txt"))
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/13/lbgl_ydd4jlcd4ht05rj1t9r0000gn/T/ipykernel_2108/72300718.py:1: SyntaxWarning: invalid escape sequence '\ '
#   pprint.pprint(ask_chatgpt(text=(input+header)('\n').strip('\ '),prompt_path="prompts/rotowire_gpt4o_make_tables.txt"))
# /var/folders/13/lbgl_ydd4jlcd4ht05rj1t9r0000gn/T/ipykernel_2108/72300718.py:1: SyntaxWarning: invalid escape sequence '\ '
#   pprint.pprint(ask_chatgpt(text=(input+header)('\n').strip('\ '),prompt_path="prompts/rotowire_gpt4o_make_tables.txt"))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 pprint.pprint(ask_chatgpt(text=(input+header)('\n').strip('\ '),prompt_path="prompts/rotowire_gpt4o_make_tables.txt"))
#
# TypeError: 'str' object is not callable

# %%
pprint.pprint(ask_gemini(
    prompt_path="prompts/rotowire_prompt_verify.txt",
    text= te.strip('\n')
))

# %%
pprint.pprint(output[idx]['response'])

# %%
pprint.pprint(output[idx]['input'])

# %%
pprint.pprint(output[idx]['response'])

# %%
df = convert_to_df(model_output_player[idx])
from tabulate import tabulate
print(tabulate(df, headers='keys', tablefmt='pretty'))
print(df)

# %%
convert_to_df(gold_table_player[idx])

# %%
convert_to_df(model_output_team[idx])

# %%
convert_to_df(gold_table_team[idx])

# %%
for i in range(0,50):
    print(i,custom_compare_tables(model_output_player[i],gold_table_player[i]))

# %%
for i in range(0,50):
    print(i,compare_values(model_output_player[i],gold_table_player[i]))

# %% [markdown]
# ## Team Table Compare

# %%
for i in range(0,50):
    print(i,custom_compare_tables(model_output_team[i],gold_table_team[i]))

# %%
for i in range(0,50):
    print(i,compare_values(model_output_team[i],gold_table_team[i]))
