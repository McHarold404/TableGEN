# %%
import pandas as pd
import numpy as np
import time
import re
import json
import pprint
from utils.table_utils import *
from utils.utils import *
from eval.eval import *
from post_processing.post_processing import *
from model_inference.gpt import *
from model_inference.gemini import *
from model_inference.llama import *
## evaluting on how many rows
output_dir = "model_outputs/llama_baseline_2610_117AM"
eval_rows = 50

# %%
# # GPT Inference extract headers
# bot = GPT4MiniBot(api_key = "",
#                   data_path="data/rotowire/test.text",
#                   prompt_path="prompts/rotowire_prompt_header_extract.txt",
#                   meta_data = None,
#                   output_path = "rotowire_headers_gpt.json",
#                   limit_rows = eval_rows)
# bot.run_inference()

# %%
## Gemini bot for extracting headers
# from model_inference.gemini import GeminiBot
# bot = GeminiBot(api_key="",
# prompt_path="prompts/rotowire_prompt_header_extract.txt",
# data_path="data/rotowire/test.text",
# output_path = 'rotowire_headers_gemini.json'
# meta_data =None,limit_rows = eval_rows)
# output = bot.run_inference()

# %%
bot = GPT4MiniBot(api_key="",
                prompt_path="prompts/rotowire_make_tables.txt",
                meta_data="model_outputs/llama_baseline_2610_117AM/ai_response.json",
                data_path=None, 
                output_path= output_dir,
                file_name = "headers.json",
                limit_rows = eval_rows)
output = bot.run_inference()
# Out:
# Starting inference
# Error reading data file: expected str, bytes or os.PathLike object, not NoneType
# Processed data point 0
# Processed data point 1
# Processed data point 2
# Processed data point 3
# Processed data point 4
# Processed data point 5
# Processed data point 6
# Processed data point 7
# Processed data point 8
# Processed data point 9
# Processed data point 10
# Processed data point 11
# Processed data point 12
# Processed data point 13
# Processed data point 14
# Processed data point 15
# Processed data point 16
# Processed data point 17
# Processed data point 18
# Processed data point 19
# Processed data point 20
# Processed data point 21
# Processed data point 22
# Processed data point 23
# Processed data point 24
# Processed data point 25
# Processed data point 26
# Processed data point 27
# Processed data point 28
# Processed data point 29
# Processed data point 30
# Processed data point 31
# Processed data point 32
# Processed data point 33
# Processed data point 34
# Processed data point 35
# Processed data point 36
# Processed data point 37
# Processed data point 38
# Processed data point 39
# Processed data point 40
# Processed data point 41
# Processed data point 42
# Processed data point 43
# Processed data point 44
# Processed data point 45
# Processed data point 46
# Processed data point 47
# Processed data point 48
# Processed data point 49
# Model output stored at model_outputs/llama_baseline_2610_117AM/headers.json
# Stored prompts at model_outputs/llama_baseline_2610_117AM/rotowire_make_tables.txt
# Finished inference
# ----------'

# %%
# from model_inference.gemini import GeminiBot
# bot = GeminiBot(api_key="",prompt_path="rotowire_prompt_make_table.txt",data_path="data/rotowire/test.text", meta_data ="rotowire_headers_gemini.json",limit_rows = eval_rows)
# output = bot.run_inference()

# %%
# bot = LlamaBot(api_key="",
#                 prompt_path="prompts/rotowire_prompt_make_table.txt",
#                 data_path="data/rotowire/test.text", 
#                 meta_data ="model_outputs/llama/llama_20241016_225614_rotowire_headers_llama.json",
#                 output_path= "model_outputs/llama/rotowire_tables.json",
#                 limit_rows = eval_rows)
# output = bot.run_inference()

# %%
# #Open (or create) a text file and write data line by line
# import json
# with open('rotowire_headers_gpt.json', 'w') as json_file:
#     json.dump(output,json_file,indent=2)

# %%
# import json
# with open('rotowire_headers_gemini.json', 'r') as json_file:
#     data = json.load(json_file)
def

# %%
# Read model responses from logs
# with open(f"{output_dir}/tables_gpt.json",'r') as f:
#     output = json.load(f)
# OR give direct output from last run
from post_processing.post_processing import process_rotowire_output
model_output_team,model_output_player,gold_table_team,gold_table_player = process_rotowire_output(output,gold_label_path = "data/rotowire/test.data",eval_rows = eval_rows)
# Out:
# Table 'Team' found for data_point 0
# Table 'Player' found for data_point 0
# Table 'Upcoming Games' found for data_point 0
# Table 'Standings' found for data_point 0
# Table 'Team' found for data_point 1
# Table 'Player' found for data_point 1
# Table 'Upcoming Games' found for data_point 1
# Table 'Team' found for data_point 2
# Table 'Player' found for data_point 2
# Table 'Upcoming Games' found for data_point 2
# Table 'Team' found for data_point 3
# Table 'Player' found for data_point 3
# Table 'Upcoming Games' found for data_point 3
# Table 'Team' found for data_point 4
# Table 'Player' found for data_point 4
# Table 'Upcoming Games' found for data_point 4
# Table 'Conference Standing' found for data_point 4
# Table 'Team' found for data_point 5
# Table 'Player' found for data_point 5
# Table 'Upcoming Games' found for data_point 5
# Table 'Team' found for data_point 6
# Table 'Player' found for data_point 6
# Table 'Game Series' found for data_point 6
# Table 'Player Status' found for data_point 6
# Table 'Team' found for data_point 7
# Table 'Player' found for data_point 7
# Table 'Upcoming Games' found for data_point 7
# Table 'Player' found for data_point 8
# Table 'Team' found for data_point 9
# Table 'Player' found for data_point 9
# Table 'Team' found for data_point 10
# Table 'Conference Position' found for data_point 10
# Table 'Player' found for data_point 10
# Table 'Team' found for data_point 11
# Table 'Player' found for data_point 11
# Table 'Team' found for data_point 12
# Table 'Player' found for data_point 12
# Table 'Bench Unit' found for data_point 12
# Table 'Team' found for data_point 13
# Table 'Player' found for data_point 13
# Table 'Upcoming Games' found for data_point 13
# Table 'Standings' found for data_point 13
# Table 'Team' found for data_point 14
# Table 'Player' found for data_point 14
# Table 'Upcoming Games' found for data_point 14
# Table 'Game Results' found for data_point 15
# Table 'Player Statistics' found for data_point 15
# Table 'Upcoming Games' found for data_point 15
# Table 'Team' found for data_point 16
# Table 'Player' found for data_point 16
# Table 'Points Score' found for data_point 16
# Table 'Team' found for data_point 17
# Table 'Player' found for data_point 17
# Table 'Team Overview' found for data_point 18
# Table 'Player Stats' found for data_point 18
# Table 'Upcoming Games' found for data_point 18
# Table 'Player' found for data_point 19
# Table 'Other Information' found for data_point 19
# Table 'Player' found for data_point 20
# Out:
# Evaluating point 0
# Evaluating point 1
# Evaluating point 2
# Evaluating point 3
# Evaluating point 4
# Evaluating point 5
# Evaluating point 6
# Evaluating point 7
# Evaluating point 8
# Evaluating point 9
# Evaluating point 10
# Evaluating point 11
# Evaluating point 12
# Evaluating point 13
# Evaluating point 14
# Evaluating point 15
# Evaluating point 16
# Evaluating point 17
# Evaluating point 18
# Evaluating point 19
# Evaluating point 20
# Evaluating point 21
# Evaluating point 22
# Evaluating point 23
# Evaluating point 24
# Evaluating point 25
# Evaluating point 26
# Evaluating point 27
# Evaluating point 28
# Evaluating point 29
# Evaluating point 30
# Evaluating point 31
# Evaluating point 32
# Evaluating point 33
# Evaluating point 34
# Evaluating point 35
# Evaluating point 36
# Evaluating point 37
# Evaluating point 38
# Evaluating point 39
# Evaluating point 40
# Evaluating point 41
# Evaluating point 42
# Evaluating point 43
# Evaluating point 44
# Evaluating point 45
# Evaluating point 46
# Evaluating point 47
# Evaluating point 48
# Evaluating point 49

# %%
# Collate results of all 
from eval import *
macro_avgs = calculate_all_macro_avgs(eval_dict,eval_exact_match=True, eval_bert=True, eval_chrf=True)

# Display the results
##macro_avgs
import json
with open(f"{output_dir}/eval_nums_collated.json", 'w') as json_file:
    json.dump(macro_avgs, json_file, indent=4)

# %%
len(eval_dict)
# Out:
# 44

# %%
pprint.pprint(macro_avgs)
# Out:
# {'Cells': {'BERT_score(%)': {'f1': 0.0, 'precision': 0.0, 'recall': 0.0},
#            'chrf(%)': {'f1': 57.86556300468644,
#                        'precision': 58.249461850833,
#                        'recall': 60.79369653628181},
#            'exact_match(%)': {'f1': 37.792617730717595,
#                               'precision': 38.38230456125947,
#                               'recall': 39.16167824934868}},
#  'Column Header': {'BERT_score(%)': {'f1': 0.0,
#                                      'precision': 0.0,
#                                      'recall': 0.0},
#                    'chrf(%)': {'f1': 65.64190882958097,
#                                'precision': 67.54148126618618,
#                                'recall': 66.25542550975598},
#                    'exact_match(%)': {'f1': 45.77192372437051,
#                                       'precision': 48.12217138921685,
#                                       'recall': 46.53328678896861}},
#  'Row Header': {'BERT_score(%)': {'f1': 0.0, 'precision': 0.0, 'recall': 0.0},
#                 'chrf(%)': {'f1': 86.81741364071145,
#                             'precision': 85.45943621496711,
#                             'recall': 89.53014468334976},
#                 'exact_match(%)': {'f1': 65.79562951590111,
#                                    'precision': 64.37457744275926,
#                                    'recall': 68.35414585414586}}}

# %% [markdown]
# ### Manual Analysis

# %%
df1 = convert_to_df(model_output_team[3])
df1

# %%
df2 = convert_to_df(gold_table_team[8])
df2

# %%
df3 = convert_to_df(model_output_player[1])
df3

# %%
df4 = convert_to_df(gold_table_player[1])
df4
